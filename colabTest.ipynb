# %% [markdown]
# <a href="https://colab.research.google.com/github/rohithreddyvennam/CollabRepository/blob/master/colabTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# My First program

# %%
print ("My first program")

# %% [markdown]
# Running Sample visualization tool

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.xlabel("numbers")
plt.ylabel("values")
plt.show()

# %% [markdown]
# Data
